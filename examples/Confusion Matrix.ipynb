# %%
import random
import typing
import itertools
from PIL import Image
import weave
from weave import storage
from weave.ecosystem import demos
weave.use_frontend_devmode()

# %%
# Not really model predictions but it'll work for now

ims = []
base_im = Image.linear_gradient('L')
for rotate in range(5):
    for shear in range(5):
        for i in range(100):
            ims.append({
                'rotate': rotate,
                'shear': shear,
                'y': random.choice(['a', 'b', 'c']),
                'x': random.randrange(10),
#                 'image': base_im
#                     .rotate(rotate * 4)
#                     .transform((256, 256), Image.AFFINE, (1, shear / 10, 0, 0, 1, 0), Image.BICUBIC)
            })
#weave.show(ims)

# %%
import hashlib
import string
import itertools
import pyarrow as pa
import weave
from weave import storage

def simple_hash(n, b):
    return int.from_bytes(hashlib.sha256(str(n).encode()).digest(), "little") % b

def create_arrow_data(n_rows, n_extra_cols):
    inner_count = int(n_rows / 25)
    #cols = {'rotate': [], 'shear': [], 'x': [], 'y': []}
    cols = {'rotate': [], 'x': [], 'y': []}
    x_choices = string.ascii_lowercase
    extra_cols = [chr(ord('a') + i) for i in range(n_extra_cols)]
    for col in extra_cols:
        cols[col] = []
    for i, (rotate, shear, _) in enumerate(
        itertools.product(range(5), range(5), range(inner_count))
    ):
        cols['rotate'].append(rotate)
        #cols['shear'].append(shear)
        cols['x'].append(x_choices[simple_hash(i**13, 5)])
        #cols['y'].append(simple_hash(i, 10))
        cols['y'].append(x_choices[simple_hash(i**13, 11)])
        for j, col in enumerate(extra_cols):
            #cols[col].append(random.random())
            cols[col].append(x_choices[simple_hash(i*13**j, 11)])
    table = pa.table(cols)
    table_list = weave.ops.ArrowTableList(table)

    return weave.ops.get(str(storage.save(table_list, 'test-table')))
ims = create_arrow_data(100000, 15)

# %%
weave.show(ims)
# Out:
#         <iframe
#             width="100%"
#             height="400px"
#             src="http://localhost:3000/index.html?fullScreen&expNode=%7B%22nodeType%22%3A%20%22output%22%2C%20%22type%22%3A%20%7B%22type%22%3A%20%22ArrowTableList%22%2C%20%22objectType%22%3A%20%7B%22type%22%3A%20%22typedDict%22%2C%20%22propertyTypes%22%3A%20%7B%22rotate%22%3A%20%22int%22%2C%20%22x%22%3A%20%22string%22%2C%20%22y%22%3A%20%22string%22%2C%20%22a%22%3A%20%22string%22%2C%20%22b%22%3A%20%22string%22%2C%20%22c%22%3A%20%22string%22%2C%20%22d%22%3A%20%22string%22%2C%20%22e%22%3A%20%22string%22%2C%20%22f%22%3A%20%22string%22%2C%20%22g%22%3A%20%22string%22%2C%20%22h%22%3A%20%22string%22%2C%20%22i%22%3A%20%22string%22%2C%20%22j%22%3A%20%22string%22%2C%20%22k%22%3A%20%22string%22%2C%20%22l%22%3A%20%22string%22%2C%20%22m%22%3A%20%22string%22%2C%20%22n%22%3A%20%22string%22%2C%20%22o%22%3A%20%22string%22%2C%20%22p%22%3A%20%22string%22%2C%20%22q%22%3A%20%22string%22%2C%20%22r%22%3A%20%22string%22%2C%20%22s%22%3A%20%22string%22%2C%20%22t%22%3A%20%22string%22%2C%20%22u%22%3A%20%22string%22%7D%7D%2C%20%22_table%22%3A%20%7B%22type%22%3A%20%22ArrowTable%22%2C%20%22objectType%22%3A%20%7B%22type%22%3A%20%22typedDict%22%2C%20%22propertyTypes%22%3A%20%7B%22rotate%22%3A%20%22int%22%2C%20%22x%22%3A%20%22string%22%2C%20%22y%22%3A%20%22string%22%2C%20%22a%22%3A%20%22string%22%2C%20%22b%22%3A%20%22string%22%2C%20%22c%22%3A%20%22string%22%2C%20%22d%22%3A%20%22string%22%2C%20%22e%22%3A%20%22string%22%2C%20%22f%22%3A%20%22string%22%2C%20%22g%22%3A%20%22string%22%2C%20%22h%22%3A%20%22string%22%2C%20%22i%22%3A%20%22string%22%2C%20%22j%22%3A%20%22string%22%2C%20%22k%22%3A%20%22string%22%2C%20%22l%22%3A%20%22string%22%2C%20%22m%22%3A%20%22string%22%2C%20%22n%22%3A%20%22string%22%2C%20%22o%22%3A%20%22string%22%2C%20%22p%22%3A%20%22string%22%2C%20%22q%22%3A%20%22string%22%2C%20%22r%22%3A%20%22string%22%2C%20%22s%22%3A%20%22string%22%2C%20%22t%22%3A%20%22string%22%2C%20%22u%22%3A%20%22string%22%7D%7D%7D%7D%2C%20%22fromOp%22%3A%20%7B%22name%22%3A%20%22get%22%2C%20%22inputs%22%3A%20%7B%22uri%22%3A%20%7B%22nodeType%22%3A%20%22const%22%2C%20%22type%22%3A%20%7B%22type%22%3A%20%22const%22%2C%20%22valType%22%3A%20%22string%22%2C%20%22val%22%3A%20%22test-table/0bd4c82b5cb895e64a1bd724abfb6faf%22%7D%2C%20%22val%22%3A%20%22test-table/0bd4c82b5cb895e64a1bd724abfb6faf%22%7D%7D%7D%7D"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
plot = weave.panels.Plot(ims)
plot.set_x(lambda row: row['rotate'])
plot.set_y(lambda row: row['x'])
weave.show(plot)

# %% [markdown]
# ## Facet is fun!

# %%
# This is one way to build a multi-confusion matrix.

# facet = weave.panels.Facet(
#     input_node=ims,
#     x=lambda im: im['rotate'],
#     y=lambda im: im['shear'],
#     select=lambda cell: weave.panels.Plot(
#         input_node=cell.groupby(
#             weave.define_fn({'row': cell.type.object_type}, lambda row: row['y'])),
#         x=lambda group: group.count(),
#         y=lambda group: group.key(),
#         label=lambda group: group.key(),
#         mark='bar',
#         no_axes=True,
#         no_legend=True
#     )
# )

facet = weave.panels.Facet(
    input_node=ims,
    x=lambda im: im['rotate'],
    y=lambda im: im['x'],
    select=lambda cell: weave.panels.Plot(
        input_node=cell.groupby(lambda row: row['y']),
        x=lambda group: group.count(),
        y=lambda group: group.key(),
        label=lambda group: group.key(),
        mark='bar',
        no_axes=True,
        no_legend=True
    )
)

weave.show(facet)
# Out:
#         <iframe
#             width="100%"
#             height="400px"
#             src="http://localhost:3000/index.html?fullScreen&expNode=%7B%22nodeType%22%3A%20%22output%22%2C%20%22type%22%3A%20%7B%22type%22%3A%20%22ArrowTableList%22%2C%20%22objectType%22%3A%20%7B%22type%22%3A%20%22typedDict%22%2C%20%22propertyTypes%22%3A%20%7B%22rotate%22%3A%20%22int%22%2C%20%22x%22%3A%20%22string%22%2C%20%22y%22%3A%20%22string%22%2C%20%22a%22%3A%20%22string%22%2C%20%22b%22%3A%20%22string%22%2C%20%22c%22%3A%20%22string%22%2C%20%22d%22%3A%20%22string%22%2C%20%22e%22%3A%20%22string%22%2C%20%22f%22%3A%20%22string%22%2C%20%22g%22%3A%20%22string%22%2C%20%22h%22%3A%20%22string%22%2C%20%22i%22%3A%20%22string%22%2C%20%22j%22%3A%20%22string%22%2C%20%22k%22%3A%20%22string%22%2C%20%22l%22%3A%20%22string%22%2C%20%22m%22%3A%20%22string%22%2C%20%22n%22%3A%20%22string%22%2C%20%22o%22%3A%20%22string%22%7D%7D%2C%20%22_table%22%3A%20%7B%22type%22%3A%20%22ArrowTable%22%2C%20%22objectType%22%3A%20%7B%22type%22%3A%20%22typedDict%22%2C%20%22propertyTypes%22%3A%20%7B%22rotate%22%3A%20%22int%22%2C%20%22x%22%3A%20%22string%22%2C%20%22y%22%3A%20%22string%22%2C%20%22a%22%3A%20%22string%22%2C%20%22b%22%3A%20%22string%22%2C%20%22c%22%3A%20%22string%22%2C%20%22d%22%3A%20%22string%22%2C%20%22e%22%3A%20%22string%22%2C%20%22f%22%3A%20%22string%22%2C%20%22g%22%3A%20%22string%22%2C%20%22h%22%3A%20%22string%22%2C%20%22i%22%3A%20%22string%22%2C%20%22j%22%3A%20%22string%22%2C%20%22k%22%3A%20%22string%22%2C%20%22l%22%3A%20%22string%22%2C%20%22m%22%3A%20%22string%22%2C%20%22n%22%3A%20%22string%22%2C%20%22o%22%3A%20%22string%22%7D%7D%7D%7D%2C%20%22fromOp%22%3A%20%7B%22name%22%3A%20%22get%22%2C%20%22inputs%22%3A%20%7B%22uri%22%3A%20%7B%22nodeType%22%3A%20%22const%22%2C%20%22type%22%3A%20%7B%22type%22%3A%20%22const%22%2C%20%22valType%22%3A%20%22string%22%2C%20%22val%22%3A%20%22test-table/9dfde3742e90f4ba72c95b90c55b1210%22%7D%2C%20%22val%22%3A%20%22test-table/9dfde3742e90f4ba72c95b90c55b1210%22%7D%7D%7D%7D&panelId=facet&panelConfig=%7B%22table%22%3A%20%7B%22autoColumns%22%3A%20false%2C%20%22columns%22%3A%20%7B%22BRJMQL6BGHXZPI%22%3A%20%7B%22panelId%22%3A%20%22%22%2C%20%22panelConfig%22%3A%20null%7D%2C%20%228VAX1J7LCIE44W%22%3A%20%7B%22panelId%22%3A%20%22%22%2C%20%22panelConfig%22%3A%20null%7D%2C%20%22NT30R2M4NFS085%22%3A%20%7B%22panelId%22%3A%20%22plot%22%2C%20%22panelConfig%22%3A%20%7B%22table%22%3A%20%7B%22autoColumns%22%3A%20false%2C%20%22columns%22%3A%20%7B%22JUYATYAZZNUITJ%22%3A%20%7B%22panelId%22%3A%20%22%22%2C%20%22panelConfig%22%3A%20null%7D%2C%20%22HBTIM5Q654CFFM%22%3A%20%7B%22panelId%22%3A%20%22%22%2C%20%22panelConfig%22%3A%20null%7D%2C%20%22JHYTI3O5VZG2NN%22%3A%20%7B%22panelId%22%3A%20%22%22%2C%20%22panelConfig%22%3A%20null%7D%2C%20%22AE1ZC5XHNQL241%22%3A%20%7B%22panelId%22%3A%20%22%22%2C%20%22panelConfig%22%3A%20null%7D%2C%20%22WZW3JPCPPXEWP9%22%3A%20%7B%22panelId%22%3A%20%22%22%2C%20%22panelConfig%22%3A%20null%7D%7D%2C%20%22preFilterFunction%22%3A%20%7B%22nodeType%22%3A%20%22void%22%2C%20%22type%22%3A%20%22invalid%22%7D%2C%20%22columnNames%22%3A%20%7B%22JUYATYAZZNUITJ%22%3A%20%22%22%2C%20%22HBTIM5Q654CFFM%22%3A%20%22%22%2C%20%22JHYTI3O5VZG2NN%22%3A%20%22%22%2C%20%22AE1ZC5XHNQL241%22%3A%20%22%22%2C%20%22WZW3JPCPPXEWP9%22%3A%20%22%22%7D%2C%20%22columnSelectFunctions%22%3A%20%7B%22JUYATYAZZNUITJ%22%3A%20%7B%22nodeType%22%3A%20%22output%22%2C%20%22type%22%3A%20%22int%22%2C%20%22fromOp%22%3A%20%7B%22name%22%3A%20%22count%22%2C%20%22inputs%22%3A%20%7B%22arr%22%3A%20%7B%22nodeType%22%3A%20%22var%22%2C%20%22type%22%3A%20%7B%22type%22%3A%20%22groupresult%22%2C%20%22objectType%22%3A%20%7B%22type%22%3A%20%22typedDict%22%2C%20%22propertyTypes%22%3A%20%7B%22rotate%22%3A%20%22int%22%2C%20%22x%22%3A%20%22string%22%2C%20%22y%22%3A%20%22string%22%2C%20%22a%22%3A%20%22string%22%2C%20%22b%22%3A%20%22string%22%2C%20%22c%22%3A%20%22string%22%2C%20%22d%22%3A%20%22string%22%2C%20%22e%22%3A%20%22string%22%2C%20%22f%22%3A%20%22string%22%2C%20%22g%22%3A%20%22string%22%2C%20%22h%22%3A%20%22string%22%2C%20%22i%22%3A%20%22string%22%2C%20%22j%22%3A%20%22string%22%2C%2 ...

# %%
# @weave.op()
# def confusion_matrix(inp: typing.Any, guess_col: str, truth_col: str, compare_col: str) -> weave.panels.Facet:
#     return weave.panels.Facet(
#         input_node=inp,
#         x=lambda i: i[guess_col],
#         y=lambda i: i[truth_col],
#         select=lambda cell: weave.panels.Plot(
#             input_node=cell.groupby(
#                 weave.define_fn({'row': cell.type.object_type}, lambda row: row[compare_col])),
#             x=lambda group: group.count(),
#             y=lambda group: group.key(),
#             label=lambda group: group.key(),
#             mark='bar',
#             no_axes=True,
#             no_legend=True
#         )
#     )

# An example of a Panel returning op. This (sort of) works but there are lots of 

@weave.op()
def confusion_matrix(inp: typing.Any, guess_col: str, truth_col: str, compare_col: str) -> weave.panels.Facet:
    return weave.panels.Facet(
        input_node=inp,
        x=lambda i: i[guess_col],
        y=lambda i: i[truth_col],
        select=lambda cell: cell.count()
    )

# %%
demos.confusion_matrix(ims, 'rotate', 'x', 'y')

# %%
# Other explorations


# weave.show(facet)

# # Not working yet, but playing with removing lambdas
# facet = weave.panels.Facet(
#     input_node=ims,
#     x=ims['rotate'],
#     y=ims['shear'],
#     select=lambda cell: weave.panels.Plot(
#         input_node=cell.groupby(cell.row['y']),
#         x=lambda group: group.count(),
#         y=lambda group: group.key(),
#         label=lambda group: group.key(),
#         mark='bar',
#         no_axes=True,
#         no_legend=True
#     )
# )

# # Maybe another cool thing
# facet = weave.panels.Facet(
#     input_node=ims,
#     x=lambda im: im['rotate'],
#     y=lambda im: im['shear'],
#     select=lambda cell_ims: cell_ims.groupby(cell.row['y'])
#         .Plot(
#             x=lambda group: group.count(),
#             y=lambda group: group.key(),
#             label=lambda group: group.key(),
#             mark='bar',
#             no_axes=True,
#             no_legend=True
#     )
# )

# # OK actually its more like we just always want to drop the first argument
# # This is finally minimal, but we can't get autocomplete help.
# facet = ims.Facet(
#     x=select('rotate'),
#     y=select('shear'),
#     select=groupby('y')
#         .Plot(
#             x=count(),
#             y=group_key(),
#             label=group_key(),
#             mark=select('bar'),
#             no_axes=True,
#             no_legend=True
#     )
# )

# # Hmm.
# facet = ims
#     .groupby(
#         facet_x=select('rotate'),
#         facet_y=select('shear'),
#         y=select('run'))
#     .count()
#     .Plot()

# facet = Plot(
#     ims,
#     facet_x=select('rotate'),
#     facet_y=select('shear'),
#     y=select('run')
#     x=count()
)

# TODO:
#   - get rid of lambdas (ims.row could be a variable?)
#     ... or we could just treat ims as the row variable when its assigned to a plot?
#   - This is why react is a little nicer, component control flow isn't usually hidden
#     away inside other components (framework style). Instead, you decide how you want to lay stuff
#     out...
#   - But we can achieve that here... We just need to make some lower level components.
#     (Try IT!) Instead of PanelFacet, use PanelLayout or PanelGrid or something
#   - see if we can get rid of groupby requirement in PanelPlot. You don't need it in Vega
#       - also maybe look at Altair API?
#
# In react you'd do:
# const ConfusionMatrix = (ims) => (
#   <Facet ...>
#     <Facet.Cell ...>
#   </Facet>
# )
