# %%
import weave
weave.use_frontend_devmode()

# %%
#table_data = weave.save([{'a': 5, 'b': 6, 'c': 'hello'}, {'a': 7, 'b': 9, 'c': 'goodbye'}], name='my-table')

# %%
weave.ops.get("local-artifact:///tmp/local-artifacts/my-table/latest")
