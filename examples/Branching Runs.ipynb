# %%
import weave
from weave import storage

# %%
import numpy as np
import random
def random_metrics(n=10, starting_index=0):
    return [{'step': starting_index + i + 1, 
             'metricA': random.random() + np.exp(i / 2), 
             'metricB': random.random() + np.exp(i / 4),
             'metricC': random.choice('ABCDEFGHIJKLMNOPQRSTUVWXYZ'),
             'metricD': np.random.rand(2, 2).tolist()}
            for i in range(n)]

root_segment = weave.ops_domain.RunSegment('my-first-run', None, 0, random_metrics(10))
ref1 = storage.save(root_segment)
segment1 = weave.ops_domain.RunSegment('my-second-run', ref1.uri, 5, random_metrics(10, 5))
ref2 = storage.save(segment1)
segment2 = weave.ops_domain.RunSegment('my-third-run', ref2.uri, 5, random_metrics(5, 10))
ref3 = storage.save(segment2)

# %%
segment2.experiment()
# Out:
#         <iframe
#             width="100%"
#             height="400px"
#             src="http://127.0.0.1:55859/__frontend/weave_jupyter/__frontend/weave_jupyter?fullScreen&expNode=%7B%22nodeType%22%3A%20%22output%22%2C%20%22type%22%3A%20%7B%22type%22%3A%20%22list%22%2C%20%22objectType%22%3A%20%7B%22type%22%3A%20%22typedDict%22%2C%20%22propertyTypes%22%3A%20%7B%22step%22%3A%20%7B%22type%22%3A%20%22union%22%2C%20%22members%22%3A%20%5B%22int%22%2C%20%22none%22%5D%7D%2C%20%22metricA%22%3A%20%7B%22type%22%3A%20%22union%22%2C%20%22members%22%3A%20%5B%22float%22%2C%20%22none%22%5D%7D%2C%20%22metricB%22%3A%20%7B%22type%22%3A%20%22union%22%2C%20%22members%22%3A%20%5B%22float%22%2C%20%22none%22%5D%7D%2C%20%22metricC%22%3A%20%7B%22type%22%3A%20%22union%22%2C%20%22members%22%3A%20%5B%22string%22%2C%20%22none%22%5D%7D%2C%20%22metricD%22%3A%20%7B%22type%22%3A%20%22union%22%2C%20%22members%22%3A%20%5B%7B%22type%22%3A%20%22list%22%2C%20%22objectType%22%3A%20%7B%22type%22%3A%20%22list%22%2C%20%22objectType%22%3A%20%22float%22%7D%7D%2C%20%22none%22%5D%7D%2C%20%22name%22%3A%20%7B%22type%22%3A%20%22union%22%2C%20%22members%22%3A%20%5B%22none%22%2C%20%22string%22%5D%7D%7D%7D%7D%2C%20%22fromOp%22%3A%20%7B%22name%22%3A%20%22RunSegment-experiment%22%2C%20%22inputs%22%3A%20%7B%22self%22%3A%20%7B%22nodeType%22%3A%20%22output%22%2C%20%22type%22%3A%20%7B%22type%22%3A%20%22RunSegment%22%2C%20%22metrics%22%3A%20%7B%22type%22%3A%20%22list%22%2C%20%22objectType%22%3A%20%7B%22type%22%3A%20%22typedDict%22%2C%20%22propertyTypes%22%3A%20%7B%22step%22%3A%20%22int%22%2C%20%22metricA%22%3A%20%22float%22%2C%20%22metricB%22%3A%20%22float%22%2C%20%22metricC%22%3A%20%22string%22%2C%20%22metricD%22%3A%20%7B%22type%22%3A%20%22list%22%2C%20%22objectType%22%3A%20%7B%22type%22%3A%20%22list%22%2C%20%22objectType%22%3A%20%22float%22%7D%7D%7D%7D%7D%2C%20%22_property_types%22%3A%20%7B%22name%22%3A%20%22string%22%2C%20%22prior_run_ref%22%3A%20%7B%22type%22%3A%20%22union%22%2C%20%22members%22%3A%20%5B%22string%22%2C%20%22none%22%5D%7D%2C%20%22resumed_from_step%22%3A%20%22int%22%2C%20%22metrics%22%3A%20%7B%22type%22%3A%20%22list%22%2C%20%22objectType%22%3A%20%22any%22%7D%7D%7D%2C%20%22fromOp%22%3A%20%7B%22name%22%3A%20%22get%22%2C%20%22inputs%22%3A%20%7B%22uri%22%3A%20%7B%22nodeType%22%3A%20%22const%22%2C%20%22type%22%3A%20%22string%22%2C%20%22val%22%3A%20%22local-artifact%3A///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be%22%7D%7D%7D%7D%7D%7D%7D"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Server request running 1 nodes.
# getReturnType("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be")
# Server request running 1 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").refine_experiment_type()
# Server request running 8 nodes.
# "inherit"
# ""
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).indexCheckpoint()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).indexCheckpoint()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).indexCheckpoint()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).indexCheckpoint()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).indexCheckpoint()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().count()
# Server request running 40 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("step")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricA")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricB")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricC")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(1).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("name")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("step")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricA")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricB")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricC")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(1).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("name")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("step")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricA")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricB")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricC")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(1).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("name")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("step")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricA")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricB")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricC")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(1).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("name")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("step")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricA")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricB")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricC")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(1).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("name")
# Server request running 5 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(1).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(1).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(1).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(1).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(1).index(0)
# Server request running 1 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(1).limit(1).count()
# Server request running 1 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(1).limit(1).index(0)
# Server request running 6 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).count()
# Server request running 22 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).index(0).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).index(1).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).index(0).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).index(1).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).index(0).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).index(1).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).index(1)
# Server request running 24 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).index(0).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).index(1).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).index(0).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).index(1).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).count()
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(0).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(1).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(2).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).index(1)
# Server request running 8 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(3).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).index(0).offset(0).limit(3).index(1)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).index(0)
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().indexCheckpoint().index(4).pick("metricD").offset(0).limit(3).index(1).offset(0).limit(3).index(1)
# Server request running 1 nodes.
# getReturnType("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be")
# Server request running 1 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").refine_experiment_type()
# Server request running 1 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().map({}.merge({step: pick(row, "step"), metricA: pick(row, "metricA"), metricC: pick(row, "metricC"), pointSize: 100, pointShape: "circle", _index: index})).unnest().list()
# Server request running 6 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().map({}.merge({step: pick(row, "step"), metricA: pick(row, "metricA"), metricC: pick(row, "metricC"), pointSize: 100, pointShape: "circle", _index: index})).index(14).pick("step")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().map({}.merge({step: pick(row, "step"), metricA: pick(row, "metricA"), metricC: pick(row, "metricC"), pointSize: 100, pointShape: "circle", _index: index})).index(14).pick("metricA")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().map({}.merge({step: pick(row, "step"), metricA: pick(row, "metricA"), metricC: pick(row, "metricC"), pointSize: 100, pointShape: "circle", _index: index})).index(14).pick("metricC")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().map({}.merge({step: pick(row, "step"), metricA: pick(row, "metricA"), metricC: pick(row, "metricC"), pointSize: 100, pointShape: "circle", _index: index})).index(14).pick("pointSize")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().map({}.merge({step: pick(row, "step"), metricA: pick(row, "metricA"), metricC: pick(row, "metricC"), pointSize: 100, pointShape: "circle", _index: index})).index(14).pick("pointShape")
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").experiment().map({}.merge({step: pick(row, "step"), metricA: pick(row, "metricA"), metricC: pick(row, "metricC"), pointSize: 100, pointShape: "circle", _index: index})).index(14).pick("_index")
# Server request running 1 nodes.
# getReturnType("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be")
# Server request running 1 nodes.
# get("local-artifact:///tmp/local-artifacts/RunSegment/10031a7a1944cb3de632d774ca8ad2be").refine_experiment_type()
