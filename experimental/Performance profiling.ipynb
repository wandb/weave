# %%
import weave
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
t = pa.table({'a': ['x', 'x', 'y'], 'b': [6, 7, 3]})
pa.table({})
# t2 = t.slice(0, 1)
#print(t.slice(0, 1))
# print(t.column_names)
# print(isinstance(a, pa.ChunkedArray))
#print(type(a))
# g = t.group_by('a')
# # print('G', g)
# a = g.aggregate([('b', 'sum'), ('b', 'mean'), ('b', 'list')])
# a0 = a.take([0])
# b_list = a0['b_list']
# print('B_LIST', type(b_list[0]), b_list[0], b_list[0].type)
# casted = b_list[0].values
# print('casted', casted, type(casted))
# t2 = pa.Table.from_arrays([b_list[0].values], names=['b'])
# print(t2)
# print(pa.array([1, 2, 3]).type)
# print('A', a.take([0]).to_pylist())
# a.schema.field('a').type
# print(a.schema[0].type == pa.int64())
#a = pa.array(np.array([1, 2, 3]))
#print(a.type)
#a[5]

# %%
import os
import cProfile
import weave
from weave import storage
import random
import time
import pyarrow as pa
from PIL import Image

def create_arrow_data(n_rows):
    inner_count = int(n_rows / 25)
    rotates = []
    shears = []
    x = []
    y = []
    random.seed(0)
    for rotate in range(5):
        for shear in range(5):
            for i in range(inner_count):
                rotates.append(rotate)
                shears.append(shear)
                x.append(random.choice(['a', 'b', 'c']))
                y.append(random.randrange(10))
    table = pa.table({
        'rotate': rotates,
        'shear': shears,
        'x': x,
        'y': y,
    })
    table_list = weave.ops.ArrowTableList(table)

    return storage.save(table_list)

def create_data(n_rows):
    inner_count = int(n_rows / 25)
    ims = []
    base_im = Image.linear_gradient("L")
    random.seed(0)
    for rotate in range(5):
        for shear in range(5):
            for i in range(inner_count):
                ims.append(
                    {
                        "rotate": rotate,
                        "shear": shear,
                        "y": random.choice(["a", "b", "c"]),
                        "x": random.randrange(10),
#                         "image": base_im.rotate(rotate * 4).transform(
#                             (256, 256),
#                             Image.AFFINE,
#                             (1, shear / 10, 0, 0, 1, 0),
#                             Image.BICUBIC,
#                         ),
                    }
                )

    return storage.save(ims)


def run(ref):
#     node = (
#         weave.get(ref)
#         .groupby(lambda row: weave.ops.dict_(rotate=row["rotate"], shear=row["shear"]))
#         .map(lambda row: row.groupby(lambda row: row["y"]))
#         .dropna()
#         .count()
#     )
    node = (
        weave.get(ref)
        # .map(lambda row: row['rotate'] + 1)
        # .map(lambda row: row + 9)
        .groupby(lambda row: weave.ops.dict_(rotate=row["rotate"], shear=row["shear"]))
        [1]
        .count()
    )
    result = weave.use(node)
    print('Run result: %s' % result)


os.system("rm -rf /tmp/local-artifacts/*")
ref = create_data(100000)
print("Data ref: ", ref)
start_time = time.time()
cProfile.run('run("%s")' % ref, "profile_stats")
print('Run time: %ss' % (time.time() - start_time))
# Out:
# Data ref:  list-obj/42b4c0b614ea067595bf2cdb81049aa6
# EXECUTION SUMMARY
# {'get:3fd577656d99e1810f9dbf2cb2f7b6c7': {'avg_time': 0.005621194839477539,
#                                           'count': 1,
#                                           'total_time': 0.005621194839477539},
#  'groupresult-count:5cacc8a937db7934c791dc82b0df100c': {'avg_time': 2.193450927734375e-05,
#                                                         'count': 1,
#                                                         'total_time': 2.193450927734375e-05},
#  'list-__getitem__:3cce1df82f392bcb975b945afb432011': {'avg_time': 4.601478576660156e-05,
#                                                        'count': 1,
#                                                        'total_time': 4.601478576660156e-05},
#  'list-groupby:55bedc8b859c006b86be0285f70dff66': {'avg_time': 2.7946553230285645,
#                                                    'count': 1,
#                                                    'total_time': 2.7946553230285645}}
# Run result: 4000
# Run time: 2.8306772708892822s

# %%
import pstats
from pstats import SortKey
p = pstats.Stats('profile_stats')
#p.strip_dirs().sort_stats(SortKey.CUMULATIVE).print_stats()
p.strip_dirs().sort_stats(SortKey.CUMULATIVE).print_callers('type_of')
#p.strip_dirs().sort_stats(SortKey.TIME).print_stats()
# Out:
#    Ordered by: cumulative time
#    List reduced from 522 to 9 due to restriction <'type_of'>
#
# Function                              was called by...
#                                           ncalls  tottime  cumtime
# weave_types.py:82(type_of)            <-       4    0.000    0.000  lazy.py:13(_ensure_node)
#                                               52    0.000    3.284  list_.py:225(type_of_instance)
#                                                4    0.000    0.000  mappers_python.py:59(apply)
#                                                7    0.000    3.285  storage.py:72(save)
#                                                2    0.000    0.000  storage.py:171(to_python)
#                                        104025/4025    0.137    3.249  weave_types.py:443(type_of_instance)
#                                           416058    0.514    1.739  weave_types.py:567(type_of_instance)
#                                               12    0.000    0.000  weave_types.py:695(type_of_instance)
# weave_types.py:144(type_of)           <- 520164/17    0.303    3.285  weave_types.py:82(type_of)
# weave_types.py:443(type_of_instance)  <-    31/6    0.110    3.285  weave_types.py:144(type_of)
# list_.py:225(type_of_instance)        <-      26    0.000    3.284  weave_types.py:144(type_of)
# weave_types.py:567(type_of_instance)  <-  104030    0.186    1.955  weave_types.py:144(type_of)
# weave_types.py:150(type_of_instance)  <-  416064    0.057    0.057  weave_types.py:144(type_of)
# weave_types.py:695(type_of_instance)  <-       4    0.000    0.000  weave_types.py:144(type_of)
# weave_types.py:765(type_of_instance)  <-       7    0.000    0.000  weave_types.py:144(type_of)
# weave_types.py:733(type_of_instance)  <-       2    0.000    0.000  weave_types.py:144(type_of)
